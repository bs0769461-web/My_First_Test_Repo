# %% [markdown]
# <a href="https://colab.research.google.com/github/bs0769461-web/My_First_Test_Repo/blob/main/1%D0%9B%D0%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная 1
#
# Вот список того, что я люблю:
# *   Спать
# *   Есть
# *   Играть
#
# ссылка на Google: [Google](https://google.com) (Ссылка)
#
# (Таблица)
# | Имя | Оценка |
# | --- | --- |
# | Артём   | 2      |
# | Егор  | 2      |
# | Тима  | 2      |
#
# (Рисунок)
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
